# %%
import requests
import pandas as pd
import time
from datetime import datetime, timedelta

# %%
baseUrl = 'https://api.polygon.io/v2'
apiKey = 'LQeVT4355IbDNjGP2HKvAFlagtPfJPL4'

# %%
def request_stock(ticker, start, end):
    url = f'{baseUrl}/aggs/ticker/{ticker}/range/1/day/{start}/{end}?apiKey={apiKey}'
    resp = requests.get(url)
    if resp.status_code != 200:
        print(f"Request Stock Error {resp.status_code}")
        return None
    return resp.json()

# %%
def get_csv(tickers):
    rsl = {}
    for i in range(len(tickers)):
        if i > 0 and i % 5 == 0:
            print("wait 60 secs...")
            time.sleep(60)
        resp = request_stock(tickers[i], '2022-01-01', '2024-12-31')
        df = pd.DataFrame(resp['results'])
        df['t'] = pd.to_datetime(df['t'], unit='ms')
        df.columns = ['volumn', 'vwap', 'open', 'close', 'high', 'low', 'time', 'num_trades']
        rsl[tickers[i]] = df
    return rsl

# %%
tickers = ['META', 'AAPL', 'AMZN', 'NFLX', 'GOOGL', 'MSFT', 'IBM', 'ORCL', 'NVDA', 'INTC']

# %%
stock_dfs = get_csv(tickers)
# Out:
# wait 60 secs...

# %%
for key, df in stock_dfs.items():
    df.to_csv(f'dataset/stocks/{key}.csv', index=False)

# %%
def request_news(ticker, end='2024-12-31'):
    url = f'{baseUrl}/reference/news?ticker={ticker}&published_utc.lte={end}&limit=1000&apiKey={apiKey}'
    resp = requests.get(url)
    if resp.status_code != 200:
        print(f"Request News Error {resp.status_code}")
        return None
    return resp.json()

# %%
def get_news(ticker):
    main_list = []
    relation_list = []
    last_date = '2024-12-31'
    for i in range(100):
        if i > 0 and i % 5 == 0:
            print("wait 60 secs...")
            time.sleep(60)
        raw_data = request_news(ticker, last_date)['results']
        last_date = raw_data[-1]['published_utc'][:10]
        
        for item in raw_data:
            if item['published_utc'].startswith(last_date):
                break
            item['ticker'] = ticker
            item['publish_time'] = datetime.fromisoformat(item['published_utc'][:-1])
            item['publisher'] = item['publisher']['name'] if 'publisher' in item else ""
            item['keywords'] = ",".join(item['keywords']) if 'keywords' in item else ""
            
            main_cols = ['id', 'publish_time', 'title', 'article_url', 
                         'ticker', 'publisher', 'description', 'keywords']
            main_list.append({k: item[k] if k in item else "" for k in main_cols})
            
            if 'insights' in item:
                for relation in item['insights']:
                    relation['news_id'] = item['id']
                    relation['source_ticker'] = item['ticker']
                    relation['time'] = item['publish_time']
                    relation_list.append(relation)
        if len(raw_data) < 1000 or last_date < '2022-11-01':
            break
    main_df = pd.DataFrame(main_list)
    relation_df = pd.DataFrame(relation_list)
    return main_df, relation_df

# %%
news_main_dfs = {}
news_relation_dfs = {}
for i in range(len(tickers)):
# Out:
#      ticker sentiment                                sentiment_reasoning  \
# 0      NVDA   neutral  Nvidia's strong growth in the data center segm...
# 1      MSFT  positive  Microsoft is identified as a major customer of...
# 2      AMZN  positive  Amazon is mentioned as one of Nvidia's top cus...
# 3      GOOG  positive  Alphabet is also identified as a major custome...
# 4     GOOGL  positive  Alphabet is also identified as a major custome...
# ...     ...       ...                                                ...
# 2052   NVDA  positive  Nvidia dominates the AI chip market and is foc...
# 2053   AVGO  positive  Broadcom is benefiting from the growing demand...
# 2054   GOOG  positive  Alphabet is one of Broadcom's large customers,...
# 2055  GOOGL  positive  Alphabet is one of Broadcom's large customers,...
# 2056   META  positive  Meta Platforms has also become an important cu...
#
#                                                 news_id source_ticker  \
# 0     40f6f17a31ea6dce828171990cd72377669fa26cabd02b...          META
# 1     40f6f17a31ea6dce828171990cd72377669fa26cabd02b...          META
# 2     40f6f17a31ea6dce828171990cd72377669fa26cabd02b...          META
# 3     40f6f17a31ea6dce828171990cd72377669fa26cabd02b...          META
# 4     40f6f17a31ea6dce828171990cd72377669fa26cabd02b...          META
# ...                                                 ...           ...
# 2052  292756ba7e603a197e999f984e4f020f4c4c6424411b51...          META
# 2053  21be967fb343c874cf942b9abe2cb4089d4500c43dc31b...          META
# 2054  21be967fb343c874cf942b9abe2cb4089d4500c43dc31b...          META
# 2055  21be967fb343c874cf942b9abe2cb4089d4500c43dc31b...          META
# 2056  21be967fb343c874cf942b9abe2cb4089d4500c43dc31b...          META
#
#                     time
# 0    2024-10-30 08:57:00
# 1    2024-10-30 08:57:00
# 2    2024-10-30 08:57:00
# 3    2024-10-30 08:57:00
# 4    2024-10-30 08:57:00
# ...                  ...
# 2052 2024-07-03 09:15:00
# 2053 2024-07-02 18:31:08
# 2054 2024-07-02 18:31:08
# 2055 2024-07-02 18:31:08
# 2056 2024-07-02 18:31:08
#
# [2057 rows x 6 columns]
